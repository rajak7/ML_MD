# %%
import numpy as np

# radial feature check
xx = np.load('./train_XX.npy')
iatom = 0
size_rad = 190
for i in range(190):
    print(i,
          xx[iatom][i], 
          xx[iatom][i+size_rad], 
          xx[iatom][i+2*size_rad])
# Out:
# 0 -0.19338377 -0.020426374 0.0009902281
# 1 -0.03487279 -0.0018847453 -0.00049085874
# 2 -0.0012921275 -2.2315426e-05 -2.5804515e-05
# 3 -4.9194066e-05 -6.402198e-07 -9.470762e-07
# 4 -3.98301e-12 -5.0006267e-14 -7.609881e-14
# 5 -0.43827817 -0.05019085 0.0018873689
# 6 -0.16978645 -0.013390945 -0.00084688416
# 7 -0.029273529 -0.00077578693 -0.0005950032
# 8 -0.0052623358 -7.9115765e-05 -0.0001037776
# 9 -1.02404e-06 -1.2856985e-08 -1.956528e-08
# 10 -0.63949084 -0.07316546 -0.0008506812
# 11 -0.34828955 -0.03423141 0.0013063813
# 12 -0.118428655 -0.0045957463 -0.0022950885
# 13 -0.042349327 -0.00081597536 -0.0008622615
# 14 -0.00026456694 -3.322752e-06 -5.055263e-06
# 15 -0.78538555 -0.0866633 -0.006700289
# 16 -0.51148826 -0.057632316 0.0054874886
# 17 -0.24733375 -0.012886587 -0.0042211497
# 18 -0.12627682 -0.0032151793 -0.002631443
# 19 -0.0048222495 -6.0675127e-05 -9.218742e-05
# 20 -1.1195637 -0.08551245 -0.049643468
# 21 -0.96850765 -0.14133129 0.023666427
# ...

# %%
import numpy as np
xx = np.load('./train_XX.npy')
iatom = 0
size_rad = 190*3
size_ang = 120

# angular feature check
for i in range(120):
    print(i+size_rad,
          xx[iatom][i+size_rad], 
          xx[iatom][i+size_ang+size_rad], 
          xx[iatom][i+2*size_ang+size_rad])
# Out:
# 570 0.19594693 0.39859986 -0.3546332
# 571 0.44821566 0.374459 0.38602996
# 572 -0.66345835 -0.7813643 -0.2234452
# 573 -0.22475788 -0.2806574 -0.044046324
# 574 0.020579915 0.16146474 -0.12161937
# 575 0.16570005 0.22111839 0.098275855
# 576 -0.36785552 -0.6120372 -0.10703263
# 577 -0.20683204 -0.3674138 -0.038162433
# 578 0.026636124 0.07145981 -0.10430707
# 579 -0.018097287 0.15562417 0.12534012
# 580 -0.015756134 -0.60991055 -0.3220332
# 581 -0.020552428 -0.44467798 -0.19710048
# 582 0.15811417 -0.02824221 -0.2868454
# 583 1.3223826 2.049149 0.96747935
# 584 -0.89339286 -1.063012 -0.1796598
# 585 0.29886207 0.53173846 0.20177983
# 586 -0.08114687 -0.051487517 0.00904034
# 587 1.2760627 1.0974779 0.0059053767
# 588 -0.75675356 -0.33859134 0.20947309
# 589 0.21757187 0.43470487 0.13129023
# 590 -0.10932643 -0.014005486 0.06364045
# 591 1.0995942 0.51244646 -0.31219816
# 592 -0.51539695 -0.045541536 0.21557117
# 593 0.24778754 0.2948306 0.0067472737
# ...
